# %%
import pandas as pd

# %%
student_data={
    "Roll_No":[101,102,103],
    "Name":["Vish","Kani","Shashi"],
    "Department":["Ds","It","Cse"],
    "Percentage":[89,92,97]
}

# %%
df=pd.DataFrame(student_data)
df.to_csv("student2.txt",sep="\t",index=False)
print("student Data Successfully Written to student_output.txt")
# Out:
# student Data Successfully Written to student_output.txt
