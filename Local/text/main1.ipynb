# %%
import pandas as pd

# %%
df=pd.read_csv("student.txt",sep="\t")

# %%
print("student data:")
print(df)
# Out:
# student data:
#   Roll_No Name    Department  Percentage
# 0                     101 Vishnu  Ds  95
# 1                 102 Kanishka    Ds  98
# 2                 103 Shashank    Ds  96
# 3                     104 Shiva   Ds  99
# 4                     105 Surya   Cse 75
